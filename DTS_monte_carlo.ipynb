# %% [markdown]
# # 1) Load and process the DAS data

# %%
import importlib
import DTS_processing_functions
importlib.reload(DTS_processing_functions)
from DTS_processing_functions import *
from tqdm import tqdm

# %%
## matching sections of the cable
matching_sections_dict = {
    ## (downgoing side) (upgoing side) and True because this has a forward and reverse part
    'ALHIC1901_22_30min': [(slice(-27.08, 312.815), slice(314.815, 654.71), True), [313.3]],
    'ALHIC1901_23_5min': [(slice(-26.3, 311.2), slice(313, 650.14), True), [311.2]],
    'ALHIC1903_23_5min': [(slice(-26.3, 311.2), slice(313, 650.14), True), [311.2]],
    'ALHIC1902_23_5min': [(slice(-26.3, 311.2), slice(313, 650.14), True), [311.2]],
    'ALHIC2301_23_5min': [(slice(-26.3, 311.2), slice(313, 650.14), True), [311.2]],
    'ALHIC2201_23_5min': [(slice(-26.3, 311.2), slice(313, 650.14), True), [311.2]],
    'ALHIC1901_23_30min': [(slice(-26.3, 311.2), slice(313, 650.14), True), [311.2]], 
    'ALHIC1902_23_30min': [(slice(-26.3, 311.2), slice(313, 650.14), True), [311.2]], 
    'ALHIC1902_23_10sec': [(slice(-26.3, 311.2), slice(313, 650.14), True), [311.2]]
}

# %%
### List of the file paths to process ###
filepaths = glob.glob('files_sorted/*')
print(filepaths)
# Out:
# ['files_sorted/ALHIC1901_23_5min', 'files_sorted/ALHIC1903_23_5min', 'files_sorted/ALHIC1902_23_5min', 'files_sorted/ALHIC2301_23_5min', 'files_sorted/ALHIC2201_23_5min', 'files_sorted/ALHIC1901_23_30min', 'files_sorted/ALHIC1902_23_30min', 'files_sorted/ALHIC1902_23_10sec', 'files_sorted/ALHIC1901_22_30min']

# %%
data = {}
for i in filepaths:
    ds = data_processing_matching_sections(i, matching_sections_dict)
    data[i[13:]] = ds
# Out:
# 11 files were found, each representing a single timestep
# 6 recorded vars were found: LAF, ST, AST, REV-ST, REV-AST, TMP
# Recorded at 3537 points along the cable
# The measurement is double ended
# Reading the data from disk
# /home/jmanos/miniconda3/envs/comcat/lib/python3.7/site-packages/dtscalibration/io.py:1834: FutureWarning: Using .astype to convert from timezone-aware dtype to timezone-naive dtype is deprecated and will raise in a future version.  Use obj.tz_localize(None) or obj.tz_convert('UTC').tz_localize(None) instead
#   for k, v in coords_zip}
# /home/jmanos/miniconda3/envs/comcat/lib/python3.7/site-packages/dtscalibration/datastore_utils.py:309: RuntimeWarning: invalid value encountered in log
#   i_f = np.log(st / ast)
# /home/jmanos/miniconda3/envs/comcat/lib/python3.7/site-packages/dtscalibration/datastore_utils.py:310: RuntimeWarning: invalid value encountered in log
#   i_b = np.log(rst / rast)
# I dont know what to do with the following data ['tmp']
# ...

# %% [markdown]
# # 2) Now let's process the data.

# %%
adjust_the_geoflux = 60

# %%
geometry = {
    ## top of borehole, below seasonal signal, bottom of borehole
    'ALHIC1901_22_30min': [162.05, 185.05+adjust_the_geoflux, 313.05],
    'ALHIC1901_23_5min': [170.43, 193.43+adjust_the_geoflux, 311.04],
    'ALHIC1903_23_5min': [163.82, 186.82+adjust_the_geoflux, 311.04],
    'ALHIC1902_23_5min': [104.07, 127.07+adjust_the_geoflux, 311.04],
    'ALHIC2301_23_5min': [220.75, 243.75+adjust_the_geoflux, 311.04],
    'ALHIC2201_23_5min': [220.0, 243.0+adjust_the_geoflux, 311.04],
    'ALHIC1901_23_30min': [170.93, 193.93+adjust_the_geoflux, 311.04], 
    'ALHIC1902_23_30min': [104.30, 127.30+adjust_the_geoflux, 311.04], 
    'ALHIC1902_23_10sec': [104.30, 127.30+adjust_the_geoflux, 311.04]
}

# %%
data_proc = {}
for i in data:
    data_proc[i] = borehole_data_reader(data, i, geometry)
# Out:
# /home/jmanos/miniconda3/envs/comcat/lib/python3.7/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in log
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jmanos/miniconda3/envs/comcat/lib/python3.7/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /home/jmanos/miniconda3/envs/comcat/lib/python3.7/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in log
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jmanos/miniconda3/envs/comcat/lib/python3.7/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /home/jmanos/miniconda3/envs/comcat/lib/python3.7/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in log
#   return func(*(_execute_task(a, cache) for a in args))
# ...

# %%
fig, ax = plt.subplots()
for i in data_proc:
    x = data_proc[i][0]
    temp = data_proc[i][2]
    ax.plot(temp, x*-1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # 3) Let's take the deepest borehole, 1902, and try to do a monte carlo

# %%
## Here what we are doing is forward modeling the steady state borehole solution
## to get as close as we can to our borehole observations.

# %%
borehole = data_proc['ALHIC1902_23_5min']

# %%
num_iterations = 10

season_amp = np.random.normal(20, 1, num_iterations)
trend_amp = np.random.normal(0, .01, num_iterations)
q_geos= np.random.normal(.049, .002, num_iterations)
long_term = np.random.normal(0, .0005, num_iterations)

fig, (ax1, ax2, ax3, ax4) = plt.subplots(4,1)
ax1.hist(season_amp)
ax2.hist(trend_amp)
ax3.hist(q_geos)
ax4.hist(long_term)
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
##Resample the borehole data to the z positions of the modeled boreholes and flip it to match the directions ##

f = interp1d(borehole[0]-borehole[0][0], borehole[2])
y_new = f(z)
y_new = y_new[::-1] #reverse 
print(y_new)
# Out:
# [-27.90975446 -28.02752053 -28.13288969 -28.2344178  -28.33940736
#  -28.45227207 -28.55766715 -28.6602579  -28.77150317 -28.8739979
#  -28.98061826 -29.08585615 -29.19828486 -29.30418488 -29.39908827
#  -29.51040533 -29.60756762 -29.71186252 -29.81480192 -29.91625442
#  -30.0095602  -30.10401869 -30.20726104 -30.29701064 -30.39331488
#  -30.48274703 -30.56038152 -30.65723282 -30.74600254 -30.8241685
#  -30.90605799 -30.97870954 -31.06101286 -31.12870697 -31.20418987
#  -31.26272036 -31.32540214 -31.39057007 -31.44982201 -31.51605319
#  -31.56663608 -31.63209567 -31.6886005  -31.75541203 -31.81465703
#  -31.89261543 -32.15975487 -32.97600436 -34.12758433 -31.34999385
#   -9.614693  ]

# %%
repeats = 1
num_steps = 5000

climate_signals = np.zeros((repeats, num_steps))
for i in range(repeats):
    climate_signals[i,:] =  brown_noise(num_steps)*.1
print(climate_signals)    
for i in climate_signals:
    print(i)
# Out:
# [[ 0.03282646 -0.03216811 -0.11591968 ... -0.06661445 -0.06255722
#   -0.05656204]]
# [ 0.03282646 -0.03216811 -0.11591968 ... -0.06661445 -0.06255722
#  -0.05656204]

# %%
counter = 0
tmin=1923
tmax=2023.25
nz=51
freq = 1
fig, (ax1, ax2, ax3) = plt.subplots(3, 1)
t = np.linspace(tmin,tmax, num_steps)
mae_arr = []
for brown_signal in climate_signals:
    for i, j, k, q in tqdm(zip(season_amp, trend_amp, long_term, q_geos)):
        anomaly = temp_timeSeries_creator(freq = freq,
                                               long_term=k,
                                               tmin = tmin,
                                               tmax=tmax,
                                               amp = i, 
                                               trend_amp=j,
                                              num_steps=num_steps)

        surface_temp = brown_signal + anomaly
        steady_state, modeled_profile, z = foreword_modeler(data_proc['ALHIC1902_23_5min'],
                                                             timeseries_toModel=surface_temp,
                                                            new_qgeo= q, 
                                                            tmin=tmin, 
                                                             tmax=tmax, 
                                                             t_steps=num_steps,
                                                            nz=nz,
                                                            model_timeseries=True,
                                                           qgeo_update=True)
        
        if counter == 0:
            ##Resample the borehole data to the z positions of the modeled boreholes and flip it to match the directions ##

            f = interp1d(borehole[0]-borehole[0][0], borehole[2])
            y_new = f(z)
            y_new = y_new[::-1] #reverse 
            counter +=1
        mae = np.sum(np.absolute(y_new - modeled_profile))
        mae_arr.append(mae)
        ax2.plot(t,surface_temp + borehole[7], c='black', alpha=0.1)
        ax3.plot(modeled_profile,z, c='lightgrey', alpha=0.1)
    ax1.plot(brown_signal)
ax3.plot(borehole[2], borehole[0][::-1], c='black', ls='--')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# 10it [00:28,  2.88s/it]

# %% [markdown]
# # 3a) So above, we pre-pick the inputs to the MCMC, but we need to learn on the fly. We will do that here.

# %%
repeats = 20
num_steps = 5000

climate_signals = np.zeros((repeats, num_steps))
for i in range(repeats):
    climate_signals[i,:] =  brown_noise(num_steps)*.2
fig = plt.figure()
plt.plot(climate_signals.T)
plt.title('Climate signals to test')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
## Initiate the array values ##
iterations = 100
num_steps = 5000

tmin=1923
tmax=2023.25
nz=51
freq = 1

m_est_arr = []
LL = []

season_amp_all = []
trend_amp_all  = []
qgeo_all = []
modeled_profile_arr = []
season_amp = np.random.normal(20, 1)
trend_amp = np.random.normal(0, .01)
q_geo= np.random.normal(.049, .002)
anomaly = temp_timeSeries_creator(freq = freq,
                                       long_term=0,
                                       tmin = tmin,
                                       tmax=tmax,
                                       amp = season_amp, 
                                       trend_amp=trend_amp,
                                      num_steps=num_steps)

surface_temp = brown_signal + anomaly

steady_state, modeled_profile, z = foreword_modeler(borehole,
                                                     timeseries_toModel=surface_temp,
                                                    new_qgeo= q_geo, 
                                                    tmin=tmin, 
                                                     tmax=tmax, 
                                                     t_steps=num_steps,
                                                    nz=nz,
                                                    model_timeseries=True,
                                                   qgeo_update=True)
f = interp1d(borehole[0]-borehole[0][0], borehole[2])
y_new = f(z)
y_new = y_new[::-1] #reverse 

L = likelihood(y_new, modeled_profile, sigma)

LL.append(L)
m_est_arr.append(surface_temp)
season_amp_all.append(season_amp)
trend_amp_all.append(trend_amp)
qgeo_all.append(q_geos)
modeled_profile_arr.append(modeled_profile)

# %%
sigma = 10

# %%
for i in climate_signals:
    for j in tqdm(range(iterations)):
        season_amp = np.random.normal(20, 1)
        trend_amp = np.random.normal(0, .01)
        q_geo= np.random.normal(.049, .002)
        anomaly = temp_timeSeries_creator(freq = freq,
                                               long_term=0,
                                               tmin = tmin,
                                               tmax=tmax,
                                               amp = season_amp, 
                                               trend_amp=trend_amp,
                                              num_steps=num_steps)

        surface_temp = brown_signal + anomaly
        steady_state, modeled_profile, z = foreword_modeler(data_proc['ALHIC1902_23_5min'],
                                                             timeseries_toModel=surface_temp,
                                                            new_qgeo= q_geo, 
                                                            tmin=tmin, 
                                                             tmax=tmax, 
                                                             t_steps=num_steps,
                                                            nz=nz,
                                                            model_timeseries=True,
                                                           qgeo_update=True)

        L = likelihood(y_new, modeled_profile, sigma)
        if L == np.nan:
            raise Exception('NaN value')
        alpha = np.random.rand() * .1
        if LL[-1] - L <= alpha:
            LL.append(L)
            m_est_arr.append(surface_temp)
            season_amp_all.append(season_amp)
            trend_amp_all.append(trend_amp)
            qgeo_all.append(q_geos)
            modeled_profile_arr.append(modeled_profile)
# Out:
# ...
# 100%|██████████| 100/100 [04:29<00:00,  2.69s/it]

# %%
fig = plt.figure()
plt.plot(np.array(modeled_profile_arr).T,z, c='lightgrey')
plt.plot(y_new,z)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure()
plt.plot(t, np.array(m_est_arr).T)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
